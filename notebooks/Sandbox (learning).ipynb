# %%
import zipfile

zip_path = "/Volumes/workspace/nba_files/landing/balldontlie_games_2026-02-19.zip"
dest = "/Volumes/workspace/nba_files/landing/"

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(dest)

# %%
display(dbutils.fs.ls("/Volumes/workspace/nba_files/landing/balldontlie/games/dt=2026-02-19"))

# %%
dbutils.fs.rm("/Volumes/workspace/nba_files/landing/balldontlie/games/.DS_Store")
dbutils.fs.rm("/Volumes/workspace/nba_files/landing/balldontlie/games/dt=2026-02-19/.DS_Store")

# %%
import os, glob

# See what's mounted at /Workspace
print("Exists /Workspace?", os.path.exists("/Workspace"))
if os.path.exists("/Workspace"):
    print(os.listdir("/Workspace")[:50])

# Search for your uploaded zip anywhere under /Workspace (can be a bit slow, but ok for Free)
matches = glob.glob("/Workspace/**/nba_bronze_landing.zip", recursive=True)
matches[:20]

# %%
import os
base_fs = "/Workspace/Users/omarhamzic1@gmail.com/nba-datalakehouse/landing"
print(os.path.exists(base_fs), base_fs)
print(os.listdir(base_fs)[:50])

# %%
display(dbutils.fs.ls("/Volumes"))

# %%
display(dbutils.fs.ls("/Volumes/<catalog>"))
display(dbutils.fs.ls("/Volumes/<catalog>/<schema>"))
display(dbutils.fs.ls("/Volumes/<catalog>/<schema>/<volume>"))

# %%
import zipfile

zip_path = "/Volumes/workspace/nba_files/landing/landing_2026-02-19.zip"
dest = "/Volumes/workspace/nba_files/landing/"

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(dest)

# %%
display(dbutils.fs.ls("/Volumes/workspace/nba_files/landing/balldontlie"))

# %%
display(dbutils.fs.ls("/Volumes/workspace/nba_files/landing/balldontlie/games"))

# %%
dbutils.fs.rm("/Volumes/workspace/nba_files/landing/landing_2026-02-19.zip")

# %%
display(dbutils.fs.ls("/Volumes/workspace/nba_files/landing/data/landing"))

# %%
src = "/Volumes/workspace/nba_files/landing/data/landing/balldontlie"
dst = "/Volumes/workspace/nba_files/landing/balldontlie"

dbutils.fs.cp(src, dst, True)

# %%
display(dbutils.fs.ls("/Volumes/workspace/nba_files/landing/balldontlie/games"))

# %%
dbutils.fs.rm("/Volumes/workspace/nba_files/landing/data", True)

# %%
base = "/Volumes/workspace/nba_files/landing/balldontlie/games"
display(dbutils.fs.ls(base))

# %%
df = spark.table("workspace.nba_bronze.the_odds_api_odds")
display(df.select("dt", "data").limit(1))

# %%
df = spark.table("workspace.nba_bronze.the_odds_api_odds")
df.selectExpr("typeof(data) as t").groupBy("t").count().show(truncate=False)
